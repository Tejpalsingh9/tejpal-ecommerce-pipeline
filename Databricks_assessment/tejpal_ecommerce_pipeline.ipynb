# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
USE CATALOG de_workspace26;

CREATE SCHEMA IF NOT EXISTS tejpal_shop;

USE tejpal_shop;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS tejpal_raw_volume;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS de_workspace26.tejpal_shop.tejpal_schema;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS de_workspace26.tejpal_shop.tejpal_checkpoints;

# %%
# Cell 1: List all scopes to confirm yours exists
scopes = dbutils.secrets.listScopes()
for s in scopes:
    print(s.name)

# %%
# Cell 2: Retrieve a dummy secret (we'll create via CLI below)
# First list keys
keys = dbutils.secrets.list("tejpal_scope")
for k in keys:
    print(k.key)

# %%
# Cell 3: Proof that secrets API works
scopes = dbutils.secrets.listScopes()
scope_names = [s.name for s in scopes]
print(f"Available scopes: {scope_names}")
print(f"tejpal_scope exists: {'tejpal_scope' in scope_names}")
print("✅ Secrets API working correctly.")
